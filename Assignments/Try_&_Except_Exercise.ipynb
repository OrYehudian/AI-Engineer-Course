# %% [markdown]
# <a href="https://colab.research.google.com/github/OrYehudian/AI-Engineer-Course/blob/main/Try_%26_Except_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 06 - Try & Except Exercise

# %% [markdown]
# ## Question 1: Cast the following variables to int. Use `try` and `except` to print a message if the casting fails

# %%
a = 17.2
b = '5'
c = False
try:
  a = int(a)
  b = int(b)
  c = int(c)

  print(a)
  print(b)
  print(c)
except:
  print("Casting fails")
# Out:
# 17
# 5
# 0

# %% [markdown]
# ## Question 2: Try to cast `val` as a float. If the casting fails, fix the problem and then cast it.

# %%
val = '17,99'

# %%
try:
  val = float(val)
except:
  val = val.replace(",",".")
  val = float(val)
print(val)
# Out:
# 17.99

# %% [markdown]
# ## Question 3: Try to cast `val2` as an int. If the casting fails, fix the problem and then cast it.

# %%
val2 = '1,000,000  '
try:
  val2 = int(val2)
except:
  val2 = val2.replace(",","")
  val2 = val2.strip()
  val2 = int(val2)
print(val2)
# Out:
# 1000000
