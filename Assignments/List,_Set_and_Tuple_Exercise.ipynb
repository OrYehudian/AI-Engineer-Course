# %% [markdown]
# <a href="https://colab.research.google.com/github/OrYehudian/AI-Engineer-Course/blob/main/List%2C_Set_and_Tuple_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 09 - List, Set and Tuple Exercise

# %% [markdown]
# [link text](https://)## Question 1: Lists

# %% [markdown]
# *Create* an empty list called `my_list`

# %%
my_list = []

# %% [markdown]
# *Add* the word 'Python'

# %%
my_list.append("python")

# %% [markdown]
# **Add** the word 'is'

# %%
my_list.append("is")

# %% [markdown]
# **Add** the word 'good'

# %%
my_list.append("good")

# %% [markdown]
# Change the third member to 'great'

# %%
my_list[2] = "great"
my_list
# Out:
# ['is', 'python', 'great']

# %% [markdown]
# **Print** `my_list`

# %%
my_list
# Out:
# ['is', 'python', 'great']

# %% [markdown]
# ## Question 2: Lists
# ### Given `lst1`, `lst2` and `lst3`, create a list called `final_lst` that combines the first three lists.

# %%
lst1 = [1,2,3]
lst2 = [4,5,6]
lst3 = [7,8,9]

# %%
final_lst = lst1 + lst2 + lst3
print(final_lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Question 3: Tuples & Sets
# ### Given `lst4`:

# %%
lst4 = ['a','b','b','b','c','d','e','e','e','e','f']

# %% [markdown]
# [link text](https://)Cast it as tuple and the save the tuple in a variable named `tup1` (without changing the value of `lst4`)

# %%
tup1 = tuple(lst4)
print(tup1)
# Out:
# ('a', 'b', 'b', 'b', 'c', 'd', 'e', 'e', 'e', 'e', 'f')

# %% [markdown]
# Cast `tup1` as a set and save it in a variable named `st1` (without changing the value of `tup1`)

# %%
st1 = set(tup1)
st1
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %% [markdown]
# What is the length of `tup1`? What is the length of `st1`?

# %%
print('The length of tup1 is',len(tup1))
print('The length of st1 is',len(st1))
# Out:
# The length of tup1 is 11
# The length of st1 is 6

# %% [markdown]
# remove the value 'f' from `lst4`

# %% [markdown]
# remove the  from `lst4`

# %% [markdown]
# [link text](https://)## Question 4: Strings
# ### Given `my_text`, print letters 7 - 12 (including both)

# %%
my_text = "Python is the best programming language there is. It is the best."

# %%
print(my_text[7:13])
# Out:
# is the

# %% [markdown]
# ## Question 5: Strings
# ### print how many words are in the `my_text`

# %%
print(len(my_text.split()))
# Out:
# 12

# %% [markdown]
# ## Question 6: Strings
# ### Given `lst5`, connect its members to create a sentence

# %%
lst5 = ['Strings','are','also','data','structures']

# %%
sentence = " ".join(lst5)
print(sentence)
# Out:
# Strings are also data structures
