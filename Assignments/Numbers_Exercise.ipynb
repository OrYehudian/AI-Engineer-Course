# %% [markdown]
# <a href="https://colab.research.google.com/github/OrYehudian/AI-Engineer-Course/blob/main/Assignments/02_Numbers_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variables Part I - Numbers

# %% [markdown]
# ## Question 1: calculate 492 X 27 and print the result

# %%
res = (492*27)
print(res)
# Out:
# 13284

# %% [markdown]
# ## Question 2: add `num1`, `num2`, and `num3`
# ## Save the result and print it

# %%
num1 = 11
num2 = 27.3
num3 = 6
result = num1 + num2 + num3
print(result)
# Out:
# 44.3

# %% [markdown]
# ## Question 3: What is the type of the result from question 2?

# %%
float
# Out:
# float

# %% [markdown]
# ## Question 4: calculate the division remainder of `a` and `b`

# %%
a = 49
b = 5
print(a%b)
# Out:
# 4

# %% [markdown]
# ## Question 5: calculate how many times `b` fits in `a`, the result must be an int (no remainder)

# %%
print(a//b)
# Out:
# 9

# %% [markdown]
# ## Question 6: given these variables containing height (cm) and weight (kg), calculate and print the BMI
#
# BMI calculation -  weight / (height in Meters ** 2)

# %%
height = 165
weight = 62
height = height / 100
res = weight / (height ** 2)
print(res)
# Out:
# 22.77318640955005

# %% [markdown]
# ## Question 7: create and calculate the following equation, in a way that the user gives the variables.
# the equation: a*b + x/y

# %%
a = int(input("Enter value a: "))
b = int(input("Enter value b: "))
x = int(input("Enter value x: "))
y = int(input("Enter value y: "))
print(a*b + x/y)
# Out:
# Enter value a: 4
# Enter value b: 5
# Enter value x: 10
# Enter value y: 2
# 25.0
