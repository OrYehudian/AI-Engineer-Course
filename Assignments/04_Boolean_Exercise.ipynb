# %% [markdown]
# <a href="https://colab.research.google.com/github/OrYehudian/AI-Engineer-Course/blob/main/Assignments/04_Boolean_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04 - Boolean Exercise

# %% [markdown]
# ## Question 1: Check if the following expressions are True or False. Print the results
#
# * $10 > 5$
# * $27 \times 8 < 15 \times 17$
# * $2^{10}+12 \times 3>= 78^2$

# %%
print(10>5)
print(27*8<15*17)
print(2**10+12*3>=78**2)
# Out:
# True
# True
# False

# %% [markdown]
# ## Question 2: Print True/False for each of the following expressions. Use the variables $a$, $b$, and $c$
#
# * $a$ is bigger than $b$, and $a$ is bigger than $c$
# * $a+b$ is smaller/equals to $c \times 20$ OR $a^{2}>b$
# * $a+b+c$ doesn't equal $c \times 20$

# %%
a = 10
b = 130
c = 7
print(a>b and a > c)
print((a+b <= c  * 20) or (a**2 > b))
print(a+b+c != c*20)
# Out:
# False
# True
# True

# %% [markdown]
# ## Question 3: Below are two strings: `s1` and `s2`. Use string methods to make them the same. Make sure that they are actualy the same

# %%
s1 = "  python iS THE best            "
s2 = "python is the best"
s1 = s1.strip().upper()
s2 = s2.strip().upper()
if(s1 == s2):
  print("same")
# Out:
# same
